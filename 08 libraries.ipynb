# %% [markdown]
# libraries: they are collection of modules and functions to perform specific tasks.
#
# Pandas: data manipulation
# Numpy(Numerical Python): multidimensional arrays and mathematical operations
#
# matplotlib,seaborn,plotly: data visualization
#
# statistics:
#
# sklearn (scikit learn): machine learning
# keras: deep learning
#
# tensorflow: google
#
# pytorch: facebook

# %% [markdown]
# Pandas are used for data manipulation, and we can create series data and dataframes data uning pandas
#
# series: contains 1D data
#
# Dataframe: contains 2D data

# %%
import pandas as pd

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
dict1 = {'id':[1,2,3],
         'name':['Anik','Raj','Sankhanil'],
         'email':['a@gmail.com','b@gmail.com','c@gmail.com'],
         'salary':[100,200,300]
}
dict1
# Out:
# {'id': [1, 2, 3],
#  'name': ['Anik', 'Raj', 'Sankhanil'],
#  'email': ['a@gmail.com', 'b@gmail.com', 'c@gmail.com'],
#  'salary': [100, 200, 300]}

# %%
df = pd.DataFrame(dict1)
df
# Out:
#    id       name        email  salary
# 0   1       Anik  a@gmail.com     100
# 1   2        Raj  b@gmail.com     200
# 2   3  Sankhanil  c@gmail.com     300

# %%
df_emp_data = pd.read_excel('data/emp_data.xlsx')
df_emp_data
# Out:
#    eid ename   sal  dept
# 0    1    aa  1234    10
# 1    2    bb  2345    20
# 2    3    cc  3214    30
# 3    4    dd  5332    40

# %%
df_mtcars = pd.read_csv('data/mtcars.csv')
df_mtcars
# Out:
#            manufacturer   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df_studata = pd.read_csv('data/studata.txt')
df_studata
# Out:
#    sid    sname            emialid address  phoneno
# 0    1    priya    priya@gmail.com     dvg     9876
# 1    2  karthik  karthik@gmail.com     blr    12345
# 2    3    karan                NaN     msr    34567

# %%
df_chipotle = pd.read_csv('data/chipotle.tsv', sep='\t')
df_chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ## reading top 10 data

# %%
df_chipotle.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
# reading bottom 10
df_chipotle.tail(10)
# Out:
#       order_id  quantity            item_name  \
# 4612      1831         1        Carnitas Bowl
# 4613      1831         1                Chips
# 4614      1831         1        Bottled Water
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25
# 4613                                                NaN     $2.15
# 4614                                                NaN     $1.50
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# ...

# %%
temp = df_chipotle.sample(10)
temp
# Out:
#       order_id  quantity                            item_name  \
# 515        215         1                          Veggie Bowl
# 2359       940         1                      Chicken Burrito
# 2951      1173         1                     Carnitas Burrito
# 315        137         2                   Chicken Salad Bowl
# 2004       808         1  Chips and Tomatillo Red Chili Salsa
# 3158      1261         2                  Chips and Guacamole
# 3303      1324         1                                Chips
# 329        143         1                        Bottled Water
# 1191       488         1  Chips and Tomatillo Red Chili Salsa
# 2801      1112         1                                Chips
#
#                                      choice_description item_price
# 515   [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $8.75
# 2359  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...     $8.75
# 2951  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     $8.99
# ...

# %%
# size chipotle data
df_chipotle.shape
# Out:
# (4622, 5)

# %%
# checking only rows
df_chipotle.shape[0]
# Out:
# 4622

# %%
# check columns
df_chipotle.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='str')

# %%
# checking datatypes
df_chipotle.dtypes
# Out:
# order_id              int64
# quantity              int64
# item_name               str
# choice_description      str
# item_price              str
# dtype: object

# %%
# check null values of each column
df_chipotle.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
# same with emp_data

# %%
# top 10
df_emp_data.head(10)
# Out:
#    eid ename   sal  dept
# 0    1    aa  1234    10
# 1    2    bb  2345    20
# 2    3    cc  3214    30
# 3    4    dd  5332    40

# %%
# bottom 10
df_emp_data.tail(10)
# Out:
#    eid ename   sal  dept
# 0    1    aa  1234    10
# 1    2    bb  2345    20
# 2    3    cc  3214    30
# 3    4    dd  5332    40

# %%
# shape
df_emp_data.shape
# Out:
# (4, 4)

# %%
# datatypes
df_emp_data.dtypes
# Out:
# eid      int64
# ename      str
# sal      int64
# dept     int64
# dtype: object

# %%
# check null values of each column
df_emp_data.isna().sum()
# Out:
# eid      0
# ename    0
# sal      0
# dept     0
# dtype: int64

# %% [markdown]
# ## Task
# - Extract data from MySQL (database connection)
# - extracr any table from pro kabbadi website data (web scrapping)
# - extract data from PDF

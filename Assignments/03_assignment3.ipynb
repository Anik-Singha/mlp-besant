# %%
# 1. Write a program to accept two integer numbers from the user and calculate their product.

num1 = int(input("Enter a number1: "))
num2 = int(input("Enter a number2: "))
print("The sum is", num1 + num2)
# Out:
# The sum is 13

# %%
# 2. Write a program to display four string “My, “Name“, “Is“, “James” as “My**Name**Is**James“.
str1 = 'My'
str2 = 'Name'
str3 = 'Is'
str4 = 'James'

print(str1,str2,str3,str4, sep ="**")
# Out:
# My**Name**Is**James

# %%
# 3. Display Decimal Number to Octal using print() function
num = 8
# The octal representation of the decimal number 8 is 10.

print('%o' % num)
# Out:
# 10

# %%
# 4. Display Float Number with 2 Decimal Place
num = 458.541315
print(round(num,2))
# Out:
# 458.54

# %%
# 5. Accept a list of 5 float numbers as an input from the user
#  Expected Output: [78.6, 78.6, 85.3, 1.2, 3.5]

num = []
for i in range(5):
    n = float(input("Enter a number: "))
    num.append(n)
print(num)
# Out:
# [3.5, 67.7, 2.09, 2.0, 45.0]

# %%
# 6. Write all content of a file into a new file by skipping line number 5

# %%
# 7.Accept any three string from one input() call
name1,name2,name3 = input("Enter three names: ").split()
print(name1,name2,name3 , sep ="\n")
# Out:
# Anik
# Ram
# Sam

# %%
# 8.Format variables using string.format() method
quantity = 3
totalMoney = 1000
price = 450
statement1 = "I have {1} dollars so I can buy {0} football for {2:.2f} dollars."
print(statement1.format(quantity, totalMoney, price))
# Out:
# I have 1000 dollars so I can buy 3 football for 450.00 dollars.

# %%
# 9.Check File is Empty or Not

# %%
# 10.Read Line Number 4 from File

# %%
# 11: Percentage Display
# numerator and a denominator. Calculate the percentage and display it with two decimal places followed by a percent sign (e.g., 75.50%).
num = int(input("Enter a numerator: "))
den = int(input("Enter a denominator: "))

print(f"The percentage is {num / den * 100:.2f}%")          # ** .2f
# Out:
# The percentage is 80.00%

# %%
# 12. Create a simple interactive menu with options like “1. Say Hello”, “2. Calculate Square”, “3. Exit”.
value = 0
while value != 3:
    print("1. Say Hello","2. Calculate Square","3. Exit", sep ="\n")
    choice = int(input("Enter your choice: "))
    if choice == 1:
        print("Hello")
    elif choice == 2:
        a = int(input("Enter a number: "))
        print("Squrare is ",a**2)
    elif choice == 3:
        value = 3
    else:
        print("Invalid choice")
# Out:
# 1. Say Hello
# 2. Calculate Square
# 3. Exit
# Squrare is  25
# 1. Say Hello
# 2. Calculate Square
# 3. Exit

# %%
# 13. Ask the user for a word and a number. Print the word right-aligned in a field of width 20, followed by the number.
"""
Enter a word:  PYnative
Enter a number:  29
            PYnative29
"""

word = input("Enter a word: ")
number = input("Enter a number: ")
print(f"{word:>20}{number}")

# %%
# 14: Tabular Output from Lists
# names = ["Alice", "Bob", "Charlie"] and scores = [85, 92, 78]. Print these lists as a simple table with columns “Name” and “Score”.

names = ["Alice", "Bob", "Charlie"]
scores = [85, 92, 78]

print(f"{'Name':<10} {'Score':<5}")
print("-" * 15)
for name, score in zip(names, scores):
    print(f"{name:<10} {score:<5}")

# %%
# 15. Ask the user for a number. Print this number padded with leading zeros to a width of 5.
# For example, if the input is 12, the output should be “00012“

number_str = input("Enter a number: ")
padded_number = number_str.zfill(5)
print(padded_number)

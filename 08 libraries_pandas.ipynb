# %% [markdown]
# libraries: they are collection of modules and functions to perform specific tasks.
#
# Pandas: data manipulation
# Numpy(Numerical Python): multidimensional arrays and mathematical operations
#
# matplotlib,seaborn,plotly: data visualization
#
# statistics:
#
# sklearn (scikit learn): machine learning
# keras: deep learning
#
# tensorflow: google
#
# pytorch: facebook

# %% [markdown]
# Pandas are used for data manipulation, and we can create series data and dataframes data uning pandas
#
# series: contains 1D data
#
# Dataframe: contains 2D data

# %%
import pandas as pd

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
dict1 = {'id':[1,2,3],
         'name':['Anik','Raj','Sankhanil'],
         'email':['a@gmail.com','b@gmail.com','c@gmail.com'],
         'salary':[100,200,300]
}
dict1
# Out:
# {'id': [1, 2, 3],
#  'name': ['Anik', 'Raj', 'Sankhanil'],
#  'email': ['a@gmail.com', 'b@gmail.com', 'c@gmail.com'],
#  'salary': [100, 200, 300]}

# %%
df = pd.DataFrame(dict1)
df
# Out:
#    id       name        email  salary
# 0   1       Anik  a@gmail.com     100
# 1   2        Raj  b@gmail.com     200
# 2   3  Sankhanil  c@gmail.com     300

# %%
df_emp_data = pd.read_excel('data/emp_data.xlsx')
df_emp_data
# Out:
#    eid ename   sal  dept
# 0    1    aa  1234    10
# 1    2    bb  2345    20
# 2    3    cc  3214    30
# 3    4    dd  5332    40

# %%
df_mtcars = pd.read_csv('data/mtcars.csv')
df_mtcars
# Out:
#            manufacturer   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df_studata = pd.read_csv('data/studata.txt')
df_studata
# Out:
#    sid    sname            emialid address  phoneno
# 0    1    priya    priya@gmail.com     dvg     9876
# 1    2  karthik  karthik@gmail.com     blr    12345
# 2    3    karan                NaN     msr    34567

# %%
df_chipotle = pd.read_csv('data/chipotle.tsv', sep='\t')
df_chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ## reading top 10 data

# %%
df_chipotle.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
# reading bottom 10
df_chipotle.tail(10)
# Out:
#       order_id  quantity            item_name  \
# 4612      1831         1        Carnitas Bowl
# 4613      1831         1                Chips
# 4614      1831         1        Bottled Water
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25
# 4613                                                NaN     $2.15
# 4614                                                NaN     $1.50
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# ...

# %%
temp = df_chipotle.sample(10)
temp
# Out:
#       order_id  quantity                     item_name  \
# 1660       671         1                  Chicken Bowl
# 4145      1658         1           Chips and Guacamole
# 3978      1594         1  Chips and Fresh Tomato Salsa
# 2782      1104         1                         Chips
# 3234      1294         1                Veggie Burrito
# 2815      1117         1                 Bottled Water
# 3782      1514         1           Chips and Guacamole
# 4137      1655         3                 Bottled Water
# 2339       932         2                  Chicken Bowl
# 3476      1396         1                   Canned Soda
#
#                                      choice_description item_price
# 1660  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     $8.49
# 4145                                                NaN     $4.45
# 3978                                                NaN     $2.95
# 2782                                                NaN     $2.15
# ...

# %%
# size chipotle data
df_chipotle.shape
# Out:
# (4622, 5)

# %%
# checking only rows
df_chipotle.shape[0]
# Out:
# 4622

# %%
# check columns
df_chipotle.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='str')

# %%
# checking datatypes
df_chipotle.dtypes
# Out:
# order_id              int64
# quantity              int64
# item_name               str
# choice_description      str
# item_price              str
# dtype: object

# %%
# check null values of each column
df_chipotle.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
# same with emp_data

# %%
# top 10
df_emp_data.head(10)
# Out:
#    eid ename   sal  dept
# 0    1    aa  1234    10
# 1    2    bb  2345    20
# 2    3    cc  3214    30
# 3    4    dd  5332    40

# %%
# bottom 10
df_emp_data.tail(10)
# Out:
#    eid ename   sal  dept
# 0    1    aa  1234    10
# 1    2    bb  2345    20
# 2    3    cc  3214    30
# 3    4    dd  5332    40

# %%
# shape
df_emp_data.shape
# Out:
# (4, 4)

# %%
# datatypes
df_emp_data.dtypes
# Out:
# eid      int64
# ename      str
# sal      int64
# dept     int64
# dtype: object

# %%
# check null values of each column
df_emp_data.isna().sum()
# Out:
# eid      0
# ename    0
# sal      0
# dept     0
# dtype: int64

# %%
df_chipotle.duplicated().sum()
# Out:
# np.int64(59)

# %%
df_mtcars.duplicated().sum()
# Out:
# np.int64(0)

# %%
# check datatypes
# check duplicates
# check null values

# %%
# How to extract individual column
df_mtcars.manufacturer
# Out:
# 0               Mazda RX4
# 1           Mazda RX4 Wag
# 2              Datsun 710
# 3          Hornet 4 Drive
# 4       Hornet Sportabout
# 5                 Valiant
# 6              Duster 360
# 7               Merc 240D
# 8                Merc 230
# 9                Merc 280
# 10              Merc 280C
# 11             Merc 450SE
# 12             Merc 450SL
# 13            Merc 450SLC
# 14     Cadillac Fleetwood
# 15    Lincoln Continental
# 16      Chrysler Imperial
# 17               Fiat 128
# 18            Honda Civic
# 19         Toyota Corolla
# 20          Toyota Corona
# 21       Dodge Challenger
# 22            AMC Javelin
# 23             Camaro Z28
# 24       Pontiac Firebird
# 25              Fiat X1-9
# 26          Porsche 914-2
# 27           Lotus Europa
# 28         Ford Pantera L
# 29           Ferrari Dino
# 30          Maserati Bora
# 31             Volvo 142E
# Name: manufacturer, dtype: str

# %%
df_mtcars['manufacturer']
# Out:
# 0               Mazda RX4
# 1           Mazda RX4 Wag
# 2              Datsun 710
# 3          Hornet 4 Drive
# 4       Hornet Sportabout
# 5                 Valiant
# 6              Duster 360
# 7               Merc 240D
# 8                Merc 230
# 9                Merc 280
# 10              Merc 280C
# 11             Merc 450SE
# 12             Merc 450SL
# 13            Merc 450SLC
# 14     Cadillac Fleetwood
# 15    Lincoln Continental
# 16      Chrysler Imperial
# 17               Fiat 128
# 18            Honda Civic
# 19         Toyota Corolla
# 20          Toyota Corona
# 21       Dodge Challenger
# 22            AMC Javelin
# 23             Camaro Z28
# 24       Pontiac Firebird
# 25              Fiat X1-9
# 26          Porsche 914-2
# 27           Lotus Europa
# 28         Ford Pantera L
# 29           Ferrari Dino
# 30          Maserati Bora
# 31             Volvo 142E
# Name: manufacturer, dtype: str

# %%
# in dataframe format
df_mtcars[['manufacturer']]
# Out:
#            manufacturer
# 0             Mazda RX4
# 1         Mazda RX4 Wag
# 2            Datsun 710
# 3        Hornet 4 Drive
# 4     Hornet Sportabout
# 5               Valiant
# 6            Duster 360
# 7             Merc 240D
# 8              Merc 230
# 9              Merc 280
# 10            Merc 280C
# 11           Merc 450SE
# 12           Merc 450SL
# 13          Merc 450SLC
# 14   Cadillac Fleetwood
# 15  Lincoln Continental
# 16    Chrysler Imperial
# 17             Fiat 128
# 18          Honda Civic
# 19       Toyota Corolla
# 20        Toyota Corona
# 21     Dodge Challenger
# 22          AMC Javelin
# 23           Camaro Z28
# 24     Pontiac Firebird
# 25            Fiat X1-9
# 26        Porsche 914-2
# 27         Lotus Europa
# 28       Ford Pantera L
# 29         Ferrari Dino
# 30        Maserati Bora
# 31           Volvo 142E

# %%
# mpg wt vs am
df_mtcars[['mpg','wt','vs','am']]

# storing in variable
temp_mtcars = df_mtcars[['mpg','wt','vs','am']]
temp_mtcars
# Out:
#      mpg     wt  vs  am
# 0   21.0  2.620   0   1
# 1   21.0  2.875   0   1
# 2   22.8  2.320   1   1
# 3   21.4  3.215   1   0
# 4   18.7  3.440   0   0
# 5   18.1  3.460   1   0
# 6   14.3  3.570   0   0
# 7   24.4  3.190   1   0
# 8   22.8  3.150   1   0
# 9   19.2  3.440   1   0
# 10  17.8  3.440   1   0
# 11  16.4  4.070   0   0
# 12  17.3  3.730   0   0
# 13  15.2  3.780   0   0
# 14  10.4  5.250   0   0
# 15  10.4  5.424   0   0
# 16  14.7  5.345   0   0
# 17  32.4  2.200   1   1
# 18  30.4  1.615   1   1
# 19  33.9  1.835   1   1
# 20  21.5  2.465   1   0
# 21  15.5  3.520   0   0
# 22  15.2  3.435   0   0
# 23  13.3  3.840   0   0
# 24  19.2  3.845   0   0
# 25  27.3  1.935   1   1
# 26  26.0  2.140   0   1
# 27  30.4  1.513   1   1
# 28  15.8  3.170   0   1
# 29  19.7  2.770   0   1
# 30  15.0  3.570   0   1
# 31  21.4  2.780   1   1

# %%
# rename column wt by weight and manufacturer as manu
df_mtcars.rename(columns={'manufacturer':'manu','wt':'weight'}, inplace=True)
df_mtcars.head()
# Out:
#                 manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90   2.620  16.46   0   1
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90   2.875  17.02   0   1
# 2         Datsun 710  22.8    4  108.0   93  3.85   2.320  18.61   1   1
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08   3.215  19.44   1   0
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15   3.440  17.02   0   0
#
#    gear  carb
# 0     4     4
# 1     4     4
# 2     4     1
# 3     3     1
# 4     3     2

# %%
# count how many unique vakyes are there in cyl column
df_mtcars['cyl'].nunique()
# Out:
# 3

# %%
# print unique elements
df_mtcars['cyl'].unique()
# Out:
# array([6, 4, 8])

# %%
# each column , number of unique
df_mtcars.nunique()
# Out:
# manu      32
# mpg       25
# cyl        3
# disp      27
# hp        22
# drat      22
# weight    29
# qsec      30
# vs         2
# am         2
# gear       3
# carb       6
# dtype: int64

# %%
# non-quantitative means where no mathmatical operation is performed

# %%
# create a column called half_qsec

df_mtcars['half_qsec'] = round(df_mtcars['qsec']/2,2)

# %%
df_mtcars
# Out:
#                    manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90   2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90   2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85   2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08   3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15   3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76   3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21   3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69   3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92   3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92   3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92   3.440  18.90   1   0
# ...

# %%
# create a column car_type
df_mtcars['car_type'] = df_mtcars['am'].map({1:'Automatic',0:'Manual'})

# %%
df_mtcars
# Out:
#                    manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90   2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90   2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85   2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08   3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15   3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76   3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21   3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69   3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92   3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92   3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92   3.440  18.90   1   0
# ...

# %%
df_mtcars["car_type1"] = ["Manual" if x == 0 else "Automatic" for x in df_mtcars["am"]]

# %%
df_mtcars
# Out:
#                    manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90   2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90   2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85   2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08   3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15   3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76   3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21   3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69   3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92   3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92   3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92   3.440  18.90   1   0
# ...

# %%
df_mtcars['car_type1'] = df_mtcars['am'].apply(lambda x: "Manual" if x == 0 else "Automatic")
df_mtcars.head()
# Out:
#                 manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90   2.620  16.46   0   1
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90   2.875  17.02   0   1
# 2         Datsun 710  22.8    4  108.0   93  3.85   2.320  18.61   1   1
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08   3.215  19.44   1   0
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15   3.440  17.02   0   0
#
#    gear  carb  half_qsec   car_type  car_type1
# 0     4     4       8.23  Automatic  Automatic
# 1     4     4       8.51  Automatic  Automatic
# 2     4     1       9.30  Automatic  Automatic
# 3     3     1       9.72     Manual     Manual
# 4     3     2       8.51     Manual     Manual

# %%
# changing present columns
df_mtcars['disp'] -= 10
df_mtcars.head()
# Out:
#                 manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  \
# 0          Mazda RX4  21.0    6  150.0  110  3.90   2.620  16.46   0   1
# 1      Mazda RX4 Wag  21.0    6  150.0  110  3.90   2.875  17.02   0   1
# 2         Datsun 710  22.8    4   98.0   93  3.85   2.320  18.61   1   1
# 3     Hornet 4 Drive  21.4    6  248.0  110  3.08   3.215  19.44   1   0
# 4  Hornet Sportabout  18.7    8  350.0  175  3.15   3.440  17.02   0   0
#
#    gear  carb  half_qsec   car_type  car_type1
# 0     4     4       8.23  Automatic  Automatic
# 1     4     4       8.51  Automatic  Automatic
# 2     4     1       9.30  Automatic  Automatic
# 3     3     1       9.72     Manual     Manual
# 4     3     2       8.51     Manual     Manual

# %%
# deleting columns
del df_mtcars['half_qsec']
df_mtcars.head()
# Out:
#                 manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  \
# 0          Mazda RX4  21.0    6  150.0  110  3.90   2.620  16.46   0   1
# 1      Mazda RX4 Wag  21.0    6  150.0  110  3.90   2.875  17.02   0   1
# 2         Datsun 710  22.8    4   98.0   93  3.85   2.320  18.61   1   1
# 3     Hornet 4 Drive  21.4    6  248.0  110  3.08   3.215  19.44   1   0
# 4  Hornet Sportabout  18.7    8  350.0  175  3.15   3.440  17.02   0   0
#
#    gear  carb   car_type  car_type1
# 0     4     4  Automatic  Automatic
# 1     4     4  Automatic  Automatic
# 2     4     1  Automatic  Automatic
# 3     3     1     Manual     Manual
# 4     3     2     Manual     Manual

# %%
# deleting multiple columns
df_mtcars.drop(columns=['car_type','car_type1'], inplace=True)
df_mtcars
# Out:
#                    manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  150.0  110  3.90   2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  150.0  110  3.90   2.875  17.02   0   1
# 2            Datsun 710  22.8    4   98.0   93  3.85   2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  248.0  110  3.08   3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  350.0  175  3.15   3.440  17.02   0   0
# 5               Valiant  18.1    6  215.0  105  2.76   3.460  20.22   1   0
# 6            Duster 360  14.3    8  350.0  245  3.21   3.570  15.84   0   0
# 7             Merc 240D  24.4    4  136.7   62  3.69   3.190  20.00   1   0
# 8              Merc 230  22.8    4  130.8   95  3.92   3.150  22.90   1   0
# 9              Merc 280  19.2    6  157.6  123  3.92   3.440  18.30   1   0
# 10            Merc 280C  17.8    6  157.6  123  3.92   3.440  18.90   1   0
# ...

# %%
# calculate mean, medain, total, max, min value of mpg column
df_mtcars['mpg'].mean()
# Out:
# np.float64(20.090625000000003)

# %%
df_mtcars['mpg'].median()
# Out:
# np.float64(19.2)

# %%
df_mtcars['mpg'].sum()
# Out:
# np.float64(642.9000000000001)

# %%
df_mtcars['mpg'].max()
# Out:
# np.float64(33.9)

# %%
df_mtcars['mpg'].min()
# Out:
# np.float64(10.4)

# %%
# describe
df_mtcars['mpg'].describe()
# Out:
# count    32.000000
# mean     20.090625
# std       6.026948
# min      10.400000
# 25%      15.425000
# 50%      19.200000
# 75%      22.800000
# max      33.900000
# Name: mpg, dtype: float64

# %%
# 1st five rows and 1st five columns
'''
DataFrame slicing:
1. iloc: using index values of ro and column
    var.iloc[rst:rsp:rss,cst:csp:css]
default start value: 0
    stop value:upto end
    step size: 1


'''
df_mtcars.iloc[:5,:5]
# Out:
#                 manu   mpg  cyl   disp   hp
# 0          Mazda RX4  21.0    6  150.0  110
# 1      Mazda RX4 Wag  21.0    6  150.0  110
# 2         Datsun 710  22.8    4   98.0   93
# 3     Hornet 4 Drive  21.4    6  248.0  110
# 4  Hornet Sportabout  18.7    8  350.0  175

# %%
df_mtcars.head(5)[df_mtcars.columns[:5]]
df_mtcars[df_mtcars.columns[:5]].head(5)
# Out:
#                 manu   mpg  cyl   disp   hp
# 0          Mazda RX4  21.0    6  150.0  110
# 1      Mazda RX4 Wag  21.0    6  150.0  110
# 2         Datsun 710  22.8    4   98.0   93
# 3     Hornet 4 Drive  21.4    6  248.0  110
# 4  Hornet Sportabout  18.7    8  350.0  175

# %%
df_mtcars.loc[df_mtcars.index[:5],df_mtcars.columns[:5]]
# Out:
#                 manu   mpg  cyl   disp   hp
# 0          Mazda RX4  21.0    6  150.0  110
# 1      Mazda RX4 Wag  21.0    6  150.0  110
# 2         Datsun 710  22.8    4   98.0   93
# 3     Hornet 4 Drive  21.4    6  248.0  110
# 4  Hornet Sportabout  18.7    8  350.0  175

# %%
# Extract all the rows with last 5 columns
df_mtcars.iloc[:,-5:]
# Out:
#      qsec  vs  am  gear  carb
# 0   16.46   0   1     4     4
# 1   17.02   0   1     4     4
# 2   18.61   1   1     4     1
# 3   19.44   1   0     3     1
# 4   17.02   0   0     3     2
# 5   20.22   1   0     3     1
# 6   15.84   0   0     3     4
# 7   20.00   1   0     4     2
# 8   22.90   1   0     4     2
# 9   18.30   1   0     4     4
# 10  18.90   1   0     4     4
# 11  17.40   0   0     3     3
# 12  17.60   0   0     3     3
# 13  18.00   0   0     3     3
# 14  17.98   0   0     3     4
# 15  17.82   0   0     3     4
# 16  17.42   0   0     3     4
# 17  19.47   1   1     4     1
# 18  18.52   1   1     4     2
# 19  19.90   1   1     4     1
# 20  20.01   1   0     3     1
# 21  16.87   0   0     3     2
# 22  17.30   0   0     3     2
# 23  15.41   0   0     3     4
# 24  17.05   0   0     3     2
# 25  18.90   1   1     4     1
# 26  16.70   0   1     5     2
# 27  16.90   1   1     5     2
# 28  14.50   0   1     5     4
# 29  15.50   0   1     5     6
# ...

# %%
# print table in reverse
df_mtcars.iloc[::-1,::-1]
# Out:
#     carb  gear  am  vs   qsec  weight  drat   hp   disp  cyl   mpg  \
# 31     2     4   1   1  18.60   2.780  4.11  109  111.0    4  21.4
# 30     8     5   1   0  14.60   3.570  3.54  335  291.0    8  15.0
# 29     6     5   1   0  15.50   2.770  3.62  175  135.0    6  19.7
# 28     4     5   1   0  14.50   3.170  4.22  264  341.0    8  15.8
# 27     2     5   1   1  16.90   1.513  3.77  113   85.1    4  30.4
# 26     2     5   1   0  16.70   2.140  4.43   91  110.3    4  26.0
# 25     1     4   1   1  18.90   1.935  4.08   66   69.0    4  27.3
# 24     2     3   0   0  17.05   3.845  3.08  175  390.0    8  19.2
# 23     4     3   0   0  15.41   3.840  3.73  245  340.0    8  13.3
# 22     2     3   0   0  17.30   3.435  3.15  150  294.0    8  15.2
# 21     2     3   0   0  16.87   3.520  2.76  150  308.0    8  15.5
# 20     1     3   0   1  20.01   2.465  3.70   97  110.1    4  21.5
# 19     1     4   1   1  19.90   1.835  4.22   65   61.1    4  33.9
# ...

# %%
# print even index rows and odd indexed columns
df_mtcars.iloc[::2,1::2]
# Out:
#      mpg   disp  drat   qsec  am  carb
# 0   21.0  150.0  3.90  16.46   1     4
# 2   22.8   98.0  3.85  18.61   1     1
# 4   18.7  350.0  3.15  17.02   0     2
# 6   14.3  350.0  3.21  15.84   0     4
# 8   22.8  130.8  3.92  22.90   0     2
# 10  17.8  157.6  3.92  18.90   0     4
# 12  17.3  265.8  3.07  17.60   0     3
# 14  10.4  462.0  2.93  17.98   0     4
# 16  14.7  430.0  3.23  17.42   0     4
# 18  30.4   65.7  4.93  18.52   1     2
# 20  21.5  110.1  3.70  20.01   0     1
# 22  15.2  294.0  3.15  17.30   0     2
# 24  19.2  390.0  3.08  17.05   0     2
# 26  26.0  110.3  4.43  16.70   1     2
# 28  15.8  341.0  4.22  14.50   1     4
# 30  15.0  291.0  3.54  14.60   1     8

# %%
#
rows1 = [2,7,11,15,20,23,28]
col = [2,6,9,11]
df_mtcars.iloc[rows1,col]
# Out:
#     cyl  weight  am  carb
# 2     4   2.320   1     1
# 7     4   3.190   0     2
# 11    8   4.070   0     3
# 15    8   5.424   0     4
# 20    4   2.465   0     1
# 23    8   3.840   0     4
# 28    8   3.170   1     4

# %%
# loc: extracting data by location name
'''
var.loc[starting name:ending name]
'''
# Out:
# '\nvar.loc[starting name:ending name]\n'

# %%
# extract 1st 10 rows with 1st 4 columns
df_mtcars.loc[df_mtcars.index[:10],df_mtcars.columns[:4]]
# Out:
#                 manu   mpg  cyl   disp
# 0          Mazda RX4  21.0    6  150.0
# 1      Mazda RX4 Wag  21.0    6  150.0
# 2         Datsun 710  22.8    4   98.0
# 3     Hornet 4 Drive  21.4    6  248.0
# 4  Hornet Sportabout  18.7    8  350.0
# 5            Valiant  18.1    6  215.0
# 6         Duster 360  14.3    8  350.0
# 7          Merc 240D  24.4    4  136.7
# 8           Merc 230  22.8    4  130.8
# 9           Merc 280  19.2    6  157.6

# %%
df_mtcars.loc[0:9,'manu':'disp']
# Out:
#                 manu   mpg  cyl   disp
# 0          Mazda RX4  21.0    6  150.0
# 1      Mazda RX4 Wag  21.0    6  150.0
# 2         Datsun 710  22.8    4   98.0
# 3     Hornet 4 Drive  21.4    6  248.0
# 4  Hornet Sportabout  18.7    8  350.0
# 5            Valiant  18.1    6  215.0
# 6         Duster 360  14.3    8  350.0
# 7          Merc 240D  24.4    4  136.7
# 8           Merc 230  22.8    4  130.8
# 9           Merc 280  19.2    6  157.6

# %%
# reverse
df_mtcars.loc[df_mtcars.index[::-1],df_mtcars.columns[::-1]]
# Out:
#     carb  gear  am  vs   qsec  weight  drat   hp   disp  cyl   mpg  \
# 31     2     4   1   1  18.60   2.780  4.11  109  111.0    4  21.4
# 30     8     5   1   0  14.60   3.570  3.54  335  291.0    8  15.0
# 29     6     5   1   0  15.50   2.770  3.62  175  135.0    6  19.7
# 28     4     5   1   0  14.50   3.170  4.22  264  341.0    8  15.8
# 27     2     5   1   1  16.90   1.513  3.77  113   85.1    4  30.4
# 26     2     5   1   0  16.70   2.140  4.43   91  110.3    4  26.0
# 25     1     4   1   1  18.90   1.935  4.08   66   69.0    4  27.3
# 24     2     3   0   0  17.05   3.845  3.08  175  390.0    8  19.2
# 23     4     3   0   0  15.41   3.840  3.73  245  340.0    8  13.3
# 22     2     3   0   0  17.30   3.435  3.15  150  294.0    8  15.2
# 21     2     3   0   0  16.87   3.520  2.76  150  308.0    8  15.5
# 20     1     3   0   1  20.01   2.465  3.70   97  110.1    4  21.5
# 19     1     4   1   1  19.90   1.835  4.22   65   61.1    4  33.9
# ...

# %%
df_mtcars.loc[::-1,'carb':'manu':-1]
df_mtcars.loc[::-1,::-1]
# Out:
#     carb  gear  am  vs   qsec  weight  drat   hp   disp  cyl   mpg  \
# 31     2     4   1   1  18.60   2.780  4.11  109  111.0    4  21.4
# 30     8     5   1   0  14.60   3.570  3.54  335  291.0    8  15.0
# 29     6     5   1   0  15.50   2.770  3.62  175  135.0    6  19.7
# 28     4     5   1   0  14.50   3.170  4.22  264  341.0    8  15.8
# 27     2     5   1   1  16.90   1.513  3.77  113   85.1    4  30.4
# 26     2     5   1   0  16.70   2.140  4.43   91  110.3    4  26.0
# 25     1     4   1   1  18.90   1.935  4.08   66   69.0    4  27.3
# 24     2     3   0   0  17.05   3.845  3.08  175  390.0    8  19.2
# 23     4     3   0   0  15.41   3.840  3.73  245  340.0    8  13.3
# 22     2     3   0   0  17.30   3.435  3.15  150  294.0    8  15.2
# 21     2     3   0   0  16.87   3.520  2.76  150  308.0    8  15.5
# 20     1     3   0   1  20.01   2.465  3.70   97  110.1    4  21.5
# 19     1     4   1   1  19.90   1.835  4.22   65   61.1    4  33.9
# ...

# %%
# all records where gear = 4
df_mtcars[df_mtcars['gear'] == 4]
# Out:
#               manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  gear  \
# 0        Mazda RX4  21.0    6  150.0  110  3.90   2.620  16.46   0   1     4
# 1    Mazda RX4 Wag  21.0    6  150.0  110  3.90   2.875  17.02   0   1     4
# 2       Datsun 710  22.8    4   98.0   93  3.85   2.320  18.61   1   1     4
# 7        Merc 240D  24.4    4  136.7   62  3.69   3.190  20.00   1   0     4
# 8         Merc 230  22.8    4  130.8   95  3.92   3.150  22.90   1   0     4
# 9         Merc 280  19.2    6  157.6  123  3.92   3.440  18.30   1   0     4
# 10       Merc 280C  17.8    6  157.6  123  3.92   3.440  18.90   1   0     4
# 17        Fiat 128  32.4    4   68.7   66  4.08   2.200  19.47   1   1     4
# 18     Honda Civic  30.4    4   65.7   52  4.93   1.615  18.52   1   1     4
# 19  Toyota Corolla  33.9    4   61.1   65  4.22   1.835  19.90   1   1     4
# 25       Fiat X1-9  27.3    4   69.0   66  4.08   1.935  18.90   1   1     4
# ...

# %%
# try to extract 4 gear car with 6 cyl
df_mtcars[(df_mtcars['gear'] == 4) & (df_mtcars['cyl'] == 6)]
# Out:
#              manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  gear  \
# 0       Mazda RX4  21.0    6  150.0  110  3.90   2.620  16.46   0   1     4
# 1   Mazda RX4 Wag  21.0    6  150.0  110  3.90   2.875  17.02   0   1     4
# 9        Merc 280  19.2    6  157.6  123  3.92   3.440  18.30   1   0     4
# 10      Merc 280C  17.8    6  157.6  123  3.92   3.440  18.90   1   0     4
#
#     carb
# 0      4
# 1      4
# 9      4
# 10     4

# %%
# extract data either 2 carb or automatic cars details

df_mtcars[(df_mtcars['am'] == 1) | (df_mtcars['carb'] == 2)]
# Out:
#                  manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  \
# 0           Mazda RX4  21.0    6  150.0  110  3.90   2.620  16.46   0   1
# 1       Mazda RX4 Wag  21.0    6  150.0  110  3.90   2.875  17.02   0   1
# 2          Datsun 710  22.8    4   98.0   93  3.85   2.320  18.61   1   1
# 4   Hornet Sportabout  18.7    8  350.0  175  3.15   3.440  17.02   0   0
# 7           Merc 240D  24.4    4  136.7   62  3.69   3.190  20.00   1   0
# 8            Merc 230  22.8    4  130.8   95  3.92   3.150  22.90   1   0
# 17           Fiat 128  32.4    4   68.7   66  4.08   2.200  19.47   1   1
# 18        Honda Civic  30.4    4   65.7   52  4.93   1.615  18.52   1   1
# 19     Toyota Corolla  33.9    4   61.1   65  4.22   1.835  19.90   1   1
# 21   Dodge Challenger  15.5    8  308.0  150  2.76   3.520  16.87   0   0
# 22        AMC Javelin  15.2    8  294.0  150  3.15   3.435  17.30   0   0
# 24   Pontiac Firebird  19.2    8  390.0  175  3.08   3.845  17.05   0   0
# ...

# %%
# extract data who's hp between 110 and 120
df_mtcars[df_mtcars['hp'].between(110,120)]
# Out:
#               manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  gear  \
# 0        Mazda RX4  21.0    6  150.0  110  3.90   2.620  16.46   0   1     4
# 1    Mazda RX4 Wag  21.0    6  150.0  110  3.90   2.875  17.02   0   1     4
# 3   Hornet 4 Drive  21.4    6  248.0  110  3.08   3.215  19.44   1   0     3
# 27    Lotus Europa  30.4    4   85.1  113  3.77   1.513  16.90   1   1     5
#
#     carb
# 0      4
# 1      4
# 3      1
# 27     2

# %%
# extract data weight between 2 to 3 or cyl 6
df_mtcars[(df_mtcars['weight'].between(2,3)) | (df_mtcars['cyl'] == 6)]
# Out:
#               manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  gear  \
# 0        Mazda RX4  21.0    6  150.0  110  3.90   2.620  16.46   0   1     4
# 1    Mazda RX4 Wag  21.0    6  150.0  110  3.90   2.875  17.02   0   1     4
# 2       Datsun 710  22.8    4   98.0   93  3.85   2.320  18.61   1   1     4
# 3   Hornet 4 Drive  21.4    6  248.0  110  3.08   3.215  19.44   1   0     3
# 5          Valiant  18.1    6  215.0  105  2.76   3.460  20.22   1   0     3
# 9         Merc 280  19.2    6  157.6  123  3.92   3.440  18.30   1   0     4
# 10       Merc 280C  17.8    6  157.6  123  3.92   3.440  18.90   1   0     4
# 17        Fiat 128  32.4    4   68.7   66  4.08   2.200  19.47   1   1     4
# 20   Toyota Corona  21.5    4  110.1   97  3.70   2.465  20.01   1   0     3
# 26   Porsche 914-2  26.0    4  110.3   91  4.43   2.140  16.70   0   1     5
# 29    Ferrari Dino  19.7    6  135.0  175  3.62   2.770  15.50   0   1     5
# ...

# %% [markdown]
# ## Comments and Keywords
#
# ### Comments
# - Comments are used to **explain the code** and improve **readability**.
# - They are **ignored by the Python interpreter** and are not executed.

# %% [markdown]
# ### Single-Line Comments
# - Single-line comments start with the symbol `#`.
# - They are used for **short explanations or notes** in the code.
#
# **Example:**
# `# This is a comment`
#
# ---
#
# ### Multi-Line Comments
# - Multi-line comments are written using triple quotes `''' '''` or `""" """`.
# - They are used for **writing comments across multiple lines or paragraphs**.
#
# **Example:**
# `'''
# Hi
# Hello
# '''`

# %% [markdown]
# ### Keywords
#
# - **Keywords** are reserved words in Python that have special meanings.
# - They **cannot be used as variable names, function names, or identifiers**.
# - Keywords define the **syntax and structure of the Python language**.
#
# **Examples:** `if`, `for`, `True`, `False`, `import`, `while`, etc.

# %%
# Output Function: print()
print("Hello World")
# Out:
# Hello World

# %%
# Input function input()
name  = input("Enter your name: ")
place = input("Enter your place: ")
print("Your name is " + name + " and place is " + place)
# Out:
# Your name is Anik and place is Bengaluru

# %%
# Format Printing
print("My name is {} and Iam from {}".format(name,place))
# Out:
# My name is Anik and Iam from Bengaluru

# %%
# f- string
print(f"My name is {name} and Iam from {place}")
# Out:
# My name is Anik and Iam from Bengaluru

# %%
# 1. WAP to add 2 numbers
num1 = int(input("Enter a number1: "))
num2 = int(input("Enter a number2: "))
print("Sum is",num1+num2)
# Out:
# Sum is 5

# %%
# 2.WAP to calculate area of rectangle
r_length = int(input("Enter length: "))
r_breadth = int(input("Enter breadth: "))
print("The area is", r_length * r_breadth)
# Out:
# The are is 40

# %% [markdown]
# ## Variables
# - It is a vlaue holder. It is used for value reusability.
#
# #### Valid Variable declaration
# - a = 5
# - A = 5
# - num = 132
# - num1 = 12
# - stu_name = 'abc'
# - _stu_id = 123
#
# #### Invalid Variable declaration
# - 1 = 5
# - stu name = 'abc'  (no space between name)
# - 1num = 245        (number can't start)
# - emp@name = 'abc'  (no special character)
# - keywords can't be used
#
#
# ### Datatypes
# #### Single Value Datatype
# - str
# - int
# - float
# - complex
# - bool
#
#
# #### Multi Value Datatype(data structures)
# - list
# - tuple
# - set
# - dict

# %%
# W WAP to take float value from user then convert that value to int

f = int(float(input("Enter a float value: ")))
print(f)
# Out:
# 4

# %% [markdown]
# ## Operators
# - arithmatic Operators + - * / % ** //
# - comparison / relational operators : == != > < >= <=
# - logical operators: and or not
# - assignment operators: =   +=  -=  *=  /=   ......
# - bitwise operators: &  |   ~   >>  <<  >>
# - membership operators: in  ,   not in
# - identity operators: is, is not
#
# Operators are special symbols used to perform certain operation between 2 operands.

# %%
5/2
# Out:
# 2.5

# %%
5//2
# Out:
# 2

# %%
5%2
# Out:
# 1

# %%
7*4     # Multiplication
# Out:
# 28

# %%
7**4    # Power
# Out:
# 2401

# %%
# Comparison Operators
# to check conditions

# %%
# Conditional Operator
# and or not

# %%
a = 5
b = 10
c = 20

# %%
a >= b and b < c or b > a
# Out:
# True

# %%
# Assignment Operators
# = += -= *= /= //= %=

# %%
0%2
# Out:
# 0

# %%
# wap to swap 2 numbers using 1. temp variable 2. without temp variable

a = 5
b = 3
c = 0

c = b
b = a
a = c
print(a, b)
# Out:
# 3 5

# %%
a = 5
b = 3

a = a-b
b = a+b
a = b-a
print(a,b)
# Out:
# 3 5
